# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy.stats import linregress

# %%
results = pd.read_csv('data/president_county_candidate.csv')
results
# Out:
#           state             county      candidate party  total_votes    won
# 0      Delaware        Kent County      Joe Biden   DEM        44552   True
# 1      Delaware        Kent County   Donald Trump   REP        41009  False
# 2      Delaware        Kent County   Jo Jorgensen   LIB         1044  False
# 3      Delaware        Kent County  Howie Hawkins   GRN          420  False
# 4      Delaware  New Castle County      Joe Biden   DEM       195034   True
# ...         ...                ...            ...   ...          ...    ...
# 31134   Arizona    Maricopa County   Donald Trump   REP       995480  False
# 31135   Arizona    Maricopa County   Jo Jorgensen   LIB        31687  False
# 31136   Arizona      Mohave County   Donald Trump   REP        78535   True
# 31137   Arizona      Mohave County      Joe Biden   DEM        24831  False
# 31138   Arizona      Mohave County   Jo Jorgensen   LIB         1302  False
#
# [31139 rows x 6 columns]

# %%
all_candidates = pd.DataFrame(results['candidate'].value_counts())
vote_count = results[["candidate", "total_votes", 'party', 'state']]
vote_count = vote_count.groupby(['candidate'])

county_count = vote_count["candidate"].count()
votes = vote_count['total_votes'].sum()
states = vote_count['state'].unique()

top_votes = pd.DataFrame({"On Ballot" : county_count,
                         "Total Votes" : votes,
                        "State" : states})

top_votes = top_votes.sort_values(["On Ballot", "Total Votes"],  ascending=[False,False])
top_votes = top_votes.iloc[2:]
top_votes
# Out:
#                            On Ballot  Total Votes  \
# candidate
# Jo Jorgensen                    4633      1818474
# Howie Hawkins                   2994       380576
#  Write-ins                      2754       155470
# Rocky De La Fuente              1562        81627
# Don Blankenship                 1317        59693
# Brock Pierce                    1124        44423
# Kanye West                      1082        65760
# Gloria La Riva                  1028        78997
# Brian Carroll                    745        24562
# Alyson Kennedy                   595         6740
# Phil Collins                     467         4681
# Kyle Kopitke                     310          809
# Blake Huber                      310          407
# Jerome Segal                     270         5440
# Brooke Paige                     246         1168
# Christopher LaFontaine           246          839
# Richard Duncan                   246          213
# Gary Swing                       246          143
# Keith McCormic                   246          127
# Zachary Scalf                    246           30
# Bill Hammons                     149         6359
# Jade Simmons                     141         5280
# Dario Hunter                     100         5293
# Ricki Sue King                    99          546
# Joe McHugh                        93         2755
# Connie Gammon                     75         1466
# John Richard Myers                75         1366
# Mark Charles                      64         1971
# President Boddie                  64         1125
# Tom Hoefling                      64          668
# Princess Jacob-Fambro             64          488
# Joseph Kishore                    64          192
# Jordan Scott                      64          173
# Jesse Ventura                     40         2109
# Sheila Samm Tittle                33         1798
#  None of these candidates         17        13422
#
#                                                                        State
# candidate
# Jo Jorgensen               [Delaware, District of Columbia, Florida, Geor...
# Howie Hawkins              [Delaware, District of Columbia, Florida, Hawa...
#  Write-ins                 [District of Columbia, Florida, Georgia, Idaho...
# Rocky De La Fuente         [Florida, Idaho, Iowa, Maine, Michigan, Minnes...
# Don Blankenship            [Florida, Hawaii, Idaho, Iowa, Louisiana, Mich...
# Brock Pierce               [District of Columbia, Hawaii, Idaho, Iowa, Ke...
# Kanye West                 [Idaho, Iowa, Kentucky, Louisiana, Minnesota, ...
# Gloria La Riva             [District of Columbia, Florida, Illinois, Loui...
# Brian Carroll              [Illinois, Louisiana, Mississippi, Rhode Islan...
# Alyson Kennedy             [Louisiana, Minnesota, Tennessee, Vermont, Was...
# Phil Collins                      [Mississippi, Vermont, Arkansas, Colorado]
# Kyle Kopitke                                             [Vermont, Colorado]
# Blake Huber                                              [Vermont, Colorado]
# Jerome Segal                                             [Maryland, Vermont]
# Brooke Paige                                                       [Vermont]
# Christopher LaFontaine                                             [Vermont]
# Richard Duncan                                                     [Vermont]
# Gary Swing                                                         [Vermont]
# Keith McCormic                                                     [Vermont]
# Zachary Scalf                                                      [Vermont]
# Bill Hammons                               [Louisiana, New Jersey, Colorado]
# Jade Simmons                                           [Louisiana, Oklahoma]
# Dario Hunter                                              [Oregon, Colorado]
# Ricki Sue King                                                        [Iowa]
# Joe McHugh                                                  [Utah, Colorado]
# Connie Gammon                                                     [Arkansas]
# John Richard Myers                                                [Arkansas]
# Mark Charles                                                      [Colorado]
# President Boddie                                                 [Louisiana]
# Tom Hoefling                                                     [Louisiana]
# Princess Jacob-Fambro                                             [Colorado]
# Joseph Kishore                                                    [Colorado]
# Jordan Scott                                                      [Colorado]
# Jesse Ventura                                                       [Alaska]
# Sheila Samm Tittle                                              [New Mexico]
#  None of these candidates                                           [Nevada]

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress((top_votes['On Ballot']), (top_votes['Total Votes']))
regress_values = (top_votes['On Ballot']) * slope + intercept
line_eq = "y = +" + str(round(slope,2)) + "x + " + str(round(intercept, 2))
plt.plot((top_votes['On Ballot']), regress_values, "r-")

plt.scatter((top_votes['On Ballot']), (top_votes['Total Votes']), marker='o', facecolors="blue", edgecolors="black", alpha=0.75)
print(f"The r-squared is: {rvalue}")
# Out:
# The r-squared is: 0.8243378661860375

# %%
candidates = results['candidate'].unique()
candidates = candidates[2:10]
candidates
# Out:
# array(['Jo Jorgensen', 'Howie Hawkins', ' Write-ins', 'Gloria La Riva',
#        'Brock Pierce', 'Rocky De La Fuente', 'Don Blankenship',
#        'Kanye West'], dtype=object)

# %%
x_axis = (candidates)
y_axis = #votes
plt.bar(x_axis, y_axis, color='g', alpha=0.5, align='center')
plt.xticks(rotation='vertical')
# Out:
#   File "<ipython-input-103-c3866e8cfb00>", line 2
#     y_axis = #votes
#                    ^
# SyntaxError: invalid syntax
